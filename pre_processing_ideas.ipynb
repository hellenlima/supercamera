# %%
import cv2
#to rotate images
rows,cols = img_norm.shape
M = cv2.getRotationMatrix2D((cols/2,rows/2),3,1)
dst = cv2.warpAffine(img_norm,M,(cols,rows))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d1f39b8a5881> in <module>()
#       1 import cv2
#       2 #to rotate images
# ----> 3 rows,cols = img_norm.shape
#       4 M = cv2.getRotationMatrix2D((cols/2,rows/2),3,1)
#       5 dst = cv2.warpAffine(img_norm,M,(cols,rows))
#
# NameError: name 'img_norm' is not defined

# %%
#calculating center of mass
from scipy import ndimage
center_mass = ndimage.measurements.center_of_mass(img_raw)

print ("center of mass",center_mass)

# %%
import cv2
import matplotlib.pyplot as plt

img_raw = cv2.imread('dois_raw.jpg') #load rgb image
hsv = cv2.cvtColor(img_raw, cv2.COLOR_BGR2HSV) #convert it to hsv

for x in range(0, len(hsv)):
    for y in range(0, len(hsv[0])):
        hsv[:,:,1] += 100
        #hsv[:,:,2] += 100
        #hsv[:,:,0] += 100

# %matplotlib inline
img = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
cv2.imwrite("image_processed.jpg", img)
plt.xticks([]), plt.yticks([])
plt.imshow(img)
